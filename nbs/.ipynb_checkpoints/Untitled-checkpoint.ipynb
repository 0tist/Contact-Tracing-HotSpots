# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import re

data = "/Users/jay.0tist/Dropbox/data/"

# %%
# df = pd.read_csv(data + 'all.csv')
# df.head()

# df.columns 

# df['District'].replace({
#     'Nashik': 'Nasik',
#     'Kalaburagi': 'Gulbarga',
#     'Bagalkote': 'Bagalkot',
#     'Prakasam': 'Ongole',
#     'South Goa': 'Margao',
#     'S.P.S. Nellore': 'Nellore',
#     'Dakshina Kannada': 'Mangalore',
#     'Thoothukkudi': 'Tuticorin',
#     'Dakshin Bastar Dantewada': 'Dantewara'
# }, inplace=True)

# # df = df.drop(columns = ['Unnamed: 0', 'objectid'])
# df = df[df.District != 'Davanagere']
# df = df[df.District != 'Chikkaballapura']
# df = df[df.District != 'Bengaluru Rural']
# df = df[df.District != 'Bengaluru Urban']
# df = df[df.District != 'Wayanad']
# df = df[df.District != 'Theni']

# import requests
# import json

# def get_city_opendata(city, country):
#     tmp = 'https://public.opendatasoft.com/api/records/1.0/search/?dataset=worldcitiespop&q=%s&sort=population&facet=country&refine.country=%s'
#     cmd = tmp % (city, country)
#     res = requests.get(cmd)
#     dct = json.loads(res.content)
#     out = dct['records'][0]['fields']
#     return out

# population = []
# for i, distr in enumerate(df['District']):
#     print(i)
#     print(distr)
#     info = get_city_opendata(distr, 'in')
#     if 'population' in info.keys():
#         population.append(info['population'])
#     else:
#         population.append(0)

# %%
df = pd.read_csv(data + 'all_with_population.csv')
df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0', 'Area (sq km)'], inplace=True)
df.dropna(subset = ["Population"], inplace=True)
df
# Out:
#      objectid              State                  District    st_area(sh  \
# 0           1        Maharashtra                   Jalgaon  1.353967e+10
# 1           2        Maharashtra                    Nashik  1.771358e+10
# 2           3        Maharashtra                Chandrapur  1.294532e+10
# 3           4        Maharashtra                  Yavatmal  1.547940e+10
# 4           5        Maharashtra                    Nanded  1.186387e+10
# ..        ...                ...                       ...           ...
# 714       719          Telangana  Jayashankar Bhupalapally  3.272979e+09
# 715       720          Telangana                Narayanpet  2.586400e+09
# 716       721  Arunachal Pradesh                  Shi-Yomi  3.442421e+09
# 718       723  Arunachal Pradesh                West Siang  1.749736e+09
# 720       725  Arunachal Pradesh                     Kamle  1.672421e+09
#
#        st_length(                                           geometry  \
# ...

# %%
long = []
lat = []
for coords in df.geometry:    
    coord = coords.split(",")
    cmp = []
    for c in coord:
        temp = re.findall(r'\d+', c) 
        pt = np.array([temp[0]+'.'+temp[1], temp[2]+'.'+temp[3]], dtype=np.float64)
        cmp.append(pt)

    cmp = np.mean(np.array(cmp), axis=0)
    long.append(cmp[0])
    lat.append(cmp[1])

# %%
df['Longitude'] = long
df['Latitude'] = lat

# %%
df.head()
# Out:
#    objectid        State    District    st_area(sh    st_length(  \
# 0         1  Maharashtra     Jalgaon  1.353967e+10  8.464308e+05
# 1         2  Maharashtra      Nashik  1.771358e+10  9.720056e+05
# 2         3  Maharashtra  Chandrapur  1.294532e+10  7.410244e+05
# 3         4  Maharashtra    Yavatmal  1.547940e+10  1.014942e+06
# 4         5  Maharashtra      Nanded  1.186387e+10  1.131732e+06
#
#                                             geometry  Confirmed  Active  \
# 0  POLYGON ((75.23334519067033 21.41480953559289,...      50098    5387
# 1  POLYGON ((74.13013381299649 20.86311429677081,...      82865   13676
# 2  POLYGON ((79.7575537026844 20.73462226435134, ...      11822    3574
# 3  POLYGON ((78.26132288530391 20.69734885711211,...       9472    1510
# 4  POLYGON ((78.05386547119404 19.92451783594126,...      17148    4312
#
#    Recovered  Deceased    Zone Population  Longitude   Latitude
# 0      43426      1285     Red  3679936.0  75.575734  20.847011
# ...

# %% [raw]
# df.drop(columns='geometry', inplace=True)
# df.head()

# %%
df.Zone.replace(to_replace='Red', value=-1, inplace=True)
df.Zone.replace(to_replace='Green', value=1, inplace=True)
df.Zone.replace(to_replace='Orange', value=0, inplace=True)
df.head()
# Out:
#    objectid        State    District    st_area(sh    st_length(  Confirmed  \
# 0         1  Maharashtra     Jalgaon  1.353967e+10  8.464308e+05      50098
# 1         2  Maharashtra      Nashik  1.771358e+10  9.720056e+05      82865
# 2         3  Maharashtra  Chandrapur  1.294532e+10  7.410244e+05      11822
# 3         4  Maharashtra    Yavatmal  1.547940e+10  1.014942e+06       9472
# 4         5  Maharashtra      Nanded  1.186387e+10  1.131732e+06      17148
#
#    Active  Recovered  Deceased  Zone Population  Longitude   Latitude
# 0    5387      43426      1285    -1  3679936.0  75.575734  20.847011
# 1   13676      67784      1405    -1  4993796.0  74.101901  20.273616
# 2    3574       8091       157     0  2071101.0  79.311941  20.131755
# 3    1510       7702       260    -1  2077144.0  78.088999  20.011792
# 4    4312      12390       446     0  2876259.0  77.607770  19.136385

# %%
df.to_csv("all_with_long_lat.csv")

# %%
df[:5]
# Out:
#    objectid        State    District    st_area(sh    st_length(  Confirmed  \
# 0         1  Maharashtra     Jalgaon  1.353967e+10  8.464308e+05      50098
# 1         2  Maharashtra      Nashik  1.771358e+10  9.720056e+05      82865
# 2         3  Maharashtra  Chandrapur  1.294532e+10  7.410244e+05      11822
# 3         4  Maharashtra    Yavatmal  1.547940e+10  1.014942e+06       9472
# 4         5  Maharashtra      Nanded  1.186387e+10  1.131732e+06      17148
#
#    Active  Recovered  Deceased  Zone Population  Longitude   Latitude
# 0    5387      43426      1285    -1  3679936.0  75.575734  20.847011
# 1   13676      67784      1405    -1  4993796.0  74.101901  20.273616
# 2    3574       8091       157     0  2071101.0  79.311941  20.131755
# 3    1510       7702       260    -1  2077144.0  78.088999  20.011792
# 4    4312      12390       446     0  2876259.0  77.607770  19.136385

# %%
df[10:15]
# Out:
#     objectid           State  District    st_area(sh     st_length(  \
# 10        11     Maharashtra    Sangli  9.475627e+09  990449.064936
# 11        12  Andhra Pradesh   Krishna  9.576532e+09  897633.025147
# 12        13       Karnataka    Yadgir  5.776520e+09  575750.286065
# 13        14       Karnataka  Bagalkot  7.147971e+09  696275.672796
# 14        15  Andhra Pradesh    Guntur  1.244717e+10  840955.608362
#
#     Confirmed  Active  Recovered  Deceased  Zone Population  Longitude  \
# 10      41147    7091      32774      1282     0  2583524.0  74.769068
# 11      30311    2733      27097       481    -1  4529009.0  80.710176
# 12       9259    1045       8158        56     1  1174271.0  76.909070
# 13      11288     671      10501       116     0    1889752  75.606803
# 14      58106    5178      52377       551    -1  4889230.0  80.181402
#
#      Latitude
# 10  17.138158
# 11  16.621238
# 12  16.580288
# 13  16.195918
# 14  16.135014

# %%
df = pd.read_csv('SoDa_MERRA2_lat4.000_lon5.000_2020-05-01_2020-05-02_1745554178.csv', delimiter=";")
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-184-27b60e1a9d9a> in <module>
# ----> 1 df = pd.read_csv('SoDa_MERRA2_lat4.000_lon5.000_2020-05-01_2020-05-02_1745554178.csv', delimiter=";")
#       2 df
#
# ...

# %%
f = open('SoDa_MERRA2_lat4.000_lon5.000_2020-05-01_2020-05-02_1745554178.csv', 'r')

for line in f:
    with open("test.csv",'w',encoding = 'utf-8') as fo:
        if(re.findall("^# Date;", line)):
            fo.write(line+'\n')
        if(re.findall("^\d", line)):
            fo.write(line+'\n')
# Out:
# Date;UT time;Temperature;Relative Humidity;Pressure;Wind speed;Wind direction;Rainfall;Snowfall;Snow depth;Short-wave irradiation
#
# 2020-05-01;01:00;302.10;74.09;1012.69;2.93;189.95;0.021404;0.000000;0.000000;0.0000
#
# 2020-05-01;02:00;302.01;75.20;1012.07;2.92;190.18;0.057185;0.000000;0.000000;0.0000
#
# 2020-05-01;03:00;301.94;76.35;1011.59;2.91;193.29;0.078052;0.000000;0.000000;0.0000
#
# 2020-05-01;04:00;301.88;77.61;1011.51;2.96;200.90;0.200951;0.000000;0.000000;0.0000
#
# 2020-05-01;05:00;301.86;78.90;1011.84;3.02;206.90;0.225091;0.000000;0.000000;0.0000
#
# 2020-05-01;06:00;301.88;79.94;1012.46;3.15;206.78;0.322294;0.000000;0.000000;3.1963
#
# 2020-05-01;07:00;301.92;80.95;1013.23;3.41;200.43;0.443959;0.000000;0.000000;45.6250
#
# 2020-05-01;08:00;301.96;82.16;1014.10;4.01;192.36;0.489664;0.000000;0.000000;114.0312
#
# 2020-05-01;09:00;301.95;83.31;1014.57;4.81;186.57;0.664759;0.000000;0.000000;180.3125
#
# ...

# %%
with open("test.txt",'w',encoding = 'utf-8') as f:
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
